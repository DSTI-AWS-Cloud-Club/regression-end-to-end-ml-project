# %%
"""" 
This script performs a smoke test of the inference pipeline with a small sample of data.
It loads a few rows of preprocessed data, runs the inference function, and displays the predictions."""

import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/feature_engineered_eval.csv"  #data/processed/cleaning_eval.csv
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# [INFO] Inference using project root: C:\Users\MATIAS\Desktop\git\regression-end-to-end-ml-project\phase-1
# Input sample:
#    year  quarter  month  median_list_price  median_ppsf  median_list_ppsf  \
# 0  2021        3      7           259900.0   145.396160        140.979244
# 1  2021        3      8           429000.0   253.164135        257.973734
# 2  2020        1      2           202500.0    99.965760        109.198464
# 3  2020        2      6           539900.0   217.805198        217.108051
# 4  2021        3      7           749400.0   349.226265        339.058053
#
#    homes_sold  pending_sales  new_listings  inventory  ...  Total Labor Force  \
# 0       104.0           98.0         107.0       66.0  ...            10937.0
# 1        82.0           95.0         117.0      126.0  ...                0.0
# 2        94.0          115.0         140.0      157.0  ...            31265.0
# 3         6.0           11.0          11.0       14.0  ...             1251.0
# ...
